# %%
#install dependancies
# !pip install datashader
# !pip install tqdm
# Out:
# Requirement already satisfied: datashader in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (0.11.1)
# Requirement already satisfied: colorcet>=0.9.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (2.0.2)
# Requirement already satisfied: pyct[cmd]==0.4.6 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (0.4.6)
# Requirement already satisfied: toolz>=0.7.4 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (0.11.1)
# Requirement already satisfied: xarray>=0.9.6 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (0.16.2)
# Requirement already satisfied: bokeh in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (2.2.3)
# Requirement already satisfied: scipy in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.5.2)
# Requirement already satisfied: dask[complete]>=0.18.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (2.30.0)
# Requirement already satisfied: pandas>=0.24.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.1.3)
# Requirement already satisfied: datashape>=0.5.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (0.5.2)
# Requirement already satisfied: numpy>=1.7 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.19.2)
# Requirement already satisfied: param>=1.6.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.10.0)
# Requirement already satisfied: pillow>=3.1.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (8.0.1)
# Requirement already satisfied: numba!=0.49.*,!=0.50.*,>=0.37.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (0.52.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (3.7.4.3)
# Requirement already satisfied: tornado>=5.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (2.8.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (5.3.1)
# Requirement already satisfied: numpy>=1.7 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.19.2)
# Requirement already satisfied: Jinja2>=2.7 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (2.11.2)
# Requirement already satisfied: packaging>=16.8 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (20.7)
# Requirement already satisfied: pillow>=3.1.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (8.0.1)
# Requirement already satisfied: param>=1.6.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.10.0)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from colorcet>=0.9.0->datashader) (0.4.6)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (5.3.1)
# Requirement already satisfied: partd>=0.3.10 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from dask[complete]>=0.18.0->datashader) (1.1.0)
# Requirement already satisfied: bokeh in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (2.2.3)
# Requirement already satisfied: cloudpickle>=0.2.2 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from dask[complete]>=0.18.0->datashader) (1.6.0)
# Requirement already satisfied: toolz>=0.7.4 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (0.11.1)
# Requirement already satisfied: numpy>=1.7 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.19.2)
# Requirement already satisfied: pandas>=0.24.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.1.3)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from dask[complete]>=0.18.0->datashader) (0.8.4)
# Requirement already satisfied: distributed>=2.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from dask[complete]>=0.18.0->datashader) (2.30.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (5.3.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (2.8.1)
# Requirement already satisfied: multipledispatch>=0.4.7 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashape>=0.5.1->datashader) (0.6.0)
# Requirement already satisfied: numpy>=1.7 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.19.2)
# Requirement already satisfied: click>=6.6 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader) (7.1.2)
# Requirement already satisfied: tornado>=5.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (6.1)
# Requirement already satisfied: zict>=0.1.3 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader) (2.0.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader) (2.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (5.3.1)
# Requirement already satisfied: toolz>=0.7.4 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (0.11.1)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader) (1.7.0)
# Requirement already satisfied: psutil>=5.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader) (5.7.3)
# Requirement already satisfied: msgpack>=0.6.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader) (1.0.0)
# Requirement already satisfied: setuptools in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader) (51.0.0.post20201207)
# Requirement already satisfied: cloudpickle>=0.2.2 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from dask[complete]>=0.18.0->datashader) (1.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from Jinja2>=2.7->bokeh->datashader) (1.1.1)
# Requirement already satisfied: six in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from multipledispatch>=0.4.7->datashape>=0.5.1->datashader) (1.15.0)
# Requirement already satisfied: setuptools in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader) (51.0.0.post20201207)
# Requirement already satisfied: numpy>=1.7 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.19.2)
# Requirement already satisfied: llvmlite<0.36,>=0.35.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from numba!=0.49.*,!=0.50.*,>=0.37.0->datashader) (0.35.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from packaging>=16.8->bokeh->datashader) (2.4.7)
# Requirement already satisfied: pytz>=2017.2 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from pandas>=0.24.1->datashader) (2020.4)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (2.8.1)
# Requirement already satisfied: numpy>=1.7 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.19.2)
# Requirement already satisfied: toolz>=0.7.4 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (0.11.1)
# Requirement already satisfied: locket in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from partd>=0.3.10->dask[complete]>=0.18.0->datashader) (0.2.0)
# Requirement already satisfied: param>=1.6.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.10.0)
# Requirement already satisfied: param>=1.6.0 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.10.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from bokeh->datashader) (5.3.1)
# Requirement already satisfied: requests in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from pyct[cmd]==0.4.6->datashader) (2.25.0)
# Requirement already satisfied: six in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from multipledispatch>=0.4.7->datashape>=0.5.1->datashader) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from requests->pyct[cmd]==0.4.6->datashader) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from requests->pyct[cmd]==0.4.6->datashader) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from requests->pyct[cmd]==0.4.6->datashader) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from requests->pyct[cmd]==0.4.6->datashader) (2.10)
# Requirement already satisfied: numpy>=1.7 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.19.2)
# Requirement already satisfied: numpy>=1.7 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.19.2)
# Requirement already satisfied: pandas>=0.24.1 in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from datashader) (1.1.3)
# Requirement already satisfied: setuptools in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader) (51.0.0.post20201207)
# Requirement already satisfied: heapdict in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (from zict>=0.1.3->distributed>=2.0->dask[complete]>=0.18.0->datashader) (1.0.1)
# Requirement already satisfied: tqdm in c:\users\vaibh\anaconda3\envs\datasc\lib\site-packages (4.54.1)

# %%
#import required libraries
import os
import time
import pandas as pd
import numpy as np
import datashader as ds
import datashader.transfer_functions as tf
from sklearn.cluster import KMeans, DBSCAN
import multiprocessing
from pathlib import Path
from pprint import pprint
from  tqdm import tqdm
import re
tqdm.pandas(desc="Progress BAR!")

# %%
#Load the csv files
DATA_PATH = Path("../data")
all_csvs = list(DATA_PATH.glob("*.csv"))
pprint(all_csvs)
# Out:
# [WindowsPath('../data/hashtag_donaldtrump.csv'),
#  WindowsPath('../data/hashtag_joebiden.csv')]

# %%
## Only pick these columns
USE_COLS = [
    'created_at', 'tweet', 'likes', 'retweet_count',
    'source', 'user_screen_name', 'lat',
    'long', 'country', 'state'
]

## Number of rows to include from each CSV
N_ROWS = 25000

# %%
#Read csv into df and combine into one 
trump = pd.read_csv(all_csvs[0],nrows=N_ROWS,usecols=USE_COLS,lineterminator="\n")
biden = pd.read_csv(all_csvs[1],nrows=N_ROWS,usecols=USE_COLS,lineterminator="\n")
df = pd.concat([trump,biden])

# %%
df.head()
# Out:
#             created_at                                              tweet  \
# 0  2020-10-15 00:00:01  #Elecciones2020 | En #Florida: #JoeBiden dice ...
# 1  2020-10-15 00:00:01  Usa 2020, Trump contro Facebook e Twitter: cop...
# 2  2020-10-15 00:00:02  #Trump: As a student I used to hear for years,...
# 3  2020-10-15 00:00:02  2 hours since last tweet from #Trump! Maybe he...
# 4  2020-10-15 00:00:08  You get a tie! And you get a tie! #Trump ‘s ra...
#
#    likes  retweet_count              source user_screen_name        lat  \
# 0    0.0            0.0           TweetDeck  elsollatinonews  25.774270
# 1   26.0            9.0    Social Mediaset   MediasetTgcom24        NaN
# 2    2.0            1.0     Twitter Web App           snarke  45.520247
# 3    0.0            0.0       Trumpytweeter    trumpytweeter        NaN
# 4    4.0            3.0  Twitter for iPhone        Ranaabtar  38.894992
#
#          long                   country                 state
# 0  -80.193660  United States of America               Florida
# 1         NaN                       NaN                   NaN
# 2 -122.674195  United States of America                Oregon
# 3         NaN                       NaN                   NaN
# 4  -77.036558  United States of America  District of Columbia

# %%
#import libraries required for cleaning
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vaibh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#Define method for cleaning tweets
stop_words = set(stopwords.words('english'))
def clean(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text=re.sub(r'@[A-Za-z0-9]+','',text)
    text=re.sub(r'#','',text)
    text=re.sub(r'RT[\s]+','',text)
    text=re.sub(r'[^\w]', ' ', text)
    filtered_tweet=[]
    words = word_tokenize(text) 
    for word in words:
        if not word in stop_words:
            filtered_tweet.append(word)
    return " ".join(filtered_tweet)

# %%
#Clean the tweets
df['ClearTweet'] = df['tweet'].progress_apply(clean)
# Out:
# Progress BAR!: 100%|██████████| 50000/50000 [00:11<00:00, 4199.67it/s]

# %%
data = df['ClearTweet'].to_list()

# %%
#use tfdif vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words=stop_words,strip_accents = "ascii",max_df=0.50,min_df=0.0002)
X = vectorizer.fit_transform(data)

# %%
print(vectorizer.get_feature_names())
print(X.shape)
# Out:
# anity', 'sans', 'sara', 'sasse', 'sat', 'satan', 'satanic', 'sataniche', 'satire', 'saudi', 'saudiarabia', 'saudis', 'savage', 'savanah', 'savanna', 'savannah', 'savannahguthrie', 'save', 'saveamerica', 'saved', 'saving', 'savings', 'savior', 'saw', 'say', 'sayin', 'saying', 'says', 'sc', 'scale', 'scam', 'scandal', 'scandale', 'scandalo', 'scandalous', 'scandals', 'scaramucci', 'scare', 'scared', 'scary', 'scenario', 'scene', 'schandaal', 'schedule', 'scheduled', 'schedules', 'scheduling', 'scheme', 'schiff', 'schon', 'school', 'schools', 'schumer', 'science', 'scientific', 'scientists', 'scoop', 'score', 'scotland', 'scott', 'scottmorrison', 'scotus', 'scotushearing', 'scotushearings', 'scranton', 'scream', 'screaming', 'screen', 'screenshot', 'screw', 'screwed', 'screwing', 'scripted', 'scrutiny', 'scully', 'scum', 'scumbag', 'se', 'sea', 'seal', 'sealed', 'seals', 'sealteamsix', 'search', 'seas', 'season', 'seat', 'seats', 'sec', 'secim', 'second', 'secondamendment', 'secondo', 'seconds', 'secret', 'secretary', 'secretly', 'secrets', 'section', 'sector', 'secure', 'security', 'see', 'seeing', 'seek', 'seeking', 'seeks', 'seem', 'seemed', 'seemingly', 'seems', 'seen', 'sees', 'segment', 'segun', 'segundo', 'sehr', 'sei', 'sein', 'seine', 'seinem', 'seinen', 'seines', 'seit', 'selbst', 'self', 'selfie', 'selfish', 'sell', 'selling', 'sellout', 'sells', 'selon', 'semanas', 'sempre', 'sen', 'senat', 'senate', 'senatedems', 'senator', 'senators', 'send', 'sending', 'sends', 'senile', 'senior', 'seniorcitizens', 'seniors', 'sense', 'sent', 'sentence', 'sentences', 'separate', 'sept', 'september', 'ser', 'sera', 'sergiomattarella', 'serial', 'series', 'serious', 'seriously', 'serve', 'served', 'serves', 'service', 'services', 'serving', 'ses', 'session', 'set', 'sets', 'setting', 'settled', 'setup', 'several', 'severe', 'sewer', 'sex', 'sexist', 'sexual', 'sexually', 'sh', 'shady', 'shaheen', 'shake', 'shaking', 'shall', 'shallow', 'shalt', 'sham', 'shame', 'shameful', 'shameless', 'shameonnbc', 'shape', 'share', 'shared', 'shares', 'sharing', 'sharp', 'shed', 'shedding', 'sheep', 'shell', 'shenanigans', 'shes', 'shiba', 'shill', 'shine', 'shinzoabe', 'ship', 'shirt', 'shirts', 'shit', 'shitler', 'shitshow', 'shitty', 'shock', 'shocked', 'shocking', 'shoes', 'shokin', 'shoot', 'shooting', 'shop', 'shopify', 'shopifyexpert', 'shoponline', 'short', 'shot', 'shots', 'shoulder', 'shout', 'shouting', 'shouts', 'show', 'showed', 'showing', 'shown', 'shows', 'shut', 'shutdown', 'shuts', 'shutting', 'si', 'sich', 'sick', 'side', 'sided', 'sides', 'sido', 'sie', 'sieht', 'siempre', 'siena', 'sight', 'sign', 'signal', 'signature', 'signed', 'signgrab', 'significant', 'signing', 'signs', 'sigue', 'silence', 'silenced', 'silencing', 'silent', 'silicon', 'siliconvalley', 'silly', 'silver', 'similar', 'simple', 'simply', 'simultaneos', 'simultaneous', 'simultaneously', 'sin', 'since', 'sincere', 'sincerely', 'sind', 'sing', 'singeingwith', 'single', 'sink', 'sinking', 'sino', 'sir', 'sirte', 'sistema', 'sister', 'sit', 'site', 'sites', 'sits', 'sitting', 'situacion', 'situation', 'situations', 'six', 'size', 'skills', 'skin', 'skip', 'sky', 'skynews', 'slammed', 'slams', 'slaughter', 'slaughtering', 'slave', 'slavery', 'sleep', 'sleepy', 'sleepyjoe', 'sleepyjoebiden', 'slightly', 'slogan', 'slot', 'slow', 'slowly', 'small', 'smart', 'smarter', 'smartnews', 'smear', 'smell', 'smh', 'smile', 'smiles', 'smoke', 'smoking', 'smokinggun', 'smokinggunemail', 'smooth', 'snake', 'sniff', 'snl', 'snowflake', 'snowflakes', 'sobre', 'social', 'socialdistancing', 'sociales', 'socialism', 'socialismkills', 'socialismo', 'socialist', 'socialists', 'socialmedia', 'socialsecurity', 'sociaux', 'societa', 'society', 'sociopath', 'soft', 'softball', 'softballs', 'sohn', 'sohnes', 'soir', 'solar', 'sold', 'soldier', 'soldiers', 'soleimani', 'solicit', 'solid', 'soll', 'sollte', 'solo', 'solution', 'solutions', 'solve', 'somebody', 'somehow', 'someone', 'something' ...
# (50000, 7296)

# %%
print(X[0,])
# Out:
#   (0, 345)	0.2979377791529677
#   (0, 1615)	0.2994709432600558
#   (0, 2656)	0.2862823094752159
#   (0, 1712)	0.2687857132560545
#   (0, 4108)	0.30566751912273693
#   (0, 2088)	0.37220855511599943
#   (0, 4851)	0.20497184954980316
#   (0, 5619)	0.20294983086742704
#   (0, 5916)	0.2539530044289595
#   (0, 1931)	0.12137038592436603
#   (0, 5122)	0.1823613669751045
#   (0, 1806)	0.2719085663864778
#   (0, 3452)	0.08760775704546085
#   (0, 2543)	0.2065202732331345
#   (0, 2141)	0.3397563859502855

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
#Use elbow method to find proper K
wcss = []
for i in range(1,11):
    km = KMeans(n_clusters=i,init='k-means++', max_iter=300, n_init=10, random_state=0)
    km.fit(X)
    wcss.append(km.inertia_)
plt.plot(range(1,11),wcss, c="#c51b7d")
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.title('Elbow Method', size=14)
plt.xlabel('Number of clusters', size=12)
plt.ylabel('wcss', size=14)
plt.show()

# %%
#train Kmeans using true K
true_k = 5
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=200, n_init=10)
model.fit(X)
labels=model.labels_

# %%
#print word clouds 
from wordcloud import WordCloud
result={'cluster':labels,'wiki':data}
result=pd.DataFrame(result)
for k in range(0,true_k):
   s=result[result.cluster==k]
   text=s['wiki'].str.cat(sep=' ')
   text=text.lower()
   text=' '.join([word for word in text.split()])
   wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
   print('Cluster: {}'.format(k))
   print('Titles')
   
   plt.figure()
   plt.imshow(wordcloud, interpolation="bilinear")
   plt.axis("off")
   plt.show()
# Out:
# Cluster: 0
# Titles
# Cluster: 1
# Titles
# Cluster: 2
# Titles
# Cluster: 3
# Titles
# Cluster: 4
# Titles
